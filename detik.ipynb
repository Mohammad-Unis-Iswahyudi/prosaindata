# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd 
import csv

#permintaan dari web browser ke web server untuk menampilkan sesuai dengan SO yang digunakan
server= {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.5481.104 Safari/537.36"}

# %%
def scrape_detik (hal):
  global server
  data=[]
  for page in range (1, hal+1):
    #print(page)
    # mengambil data banjir kemudian diurutkan berdasarkan waktu dan halaman
    url = f"https://www.detik.com/search/searchall?query=sandiaga+uno&siteid={page}"
    request = req.get(url,server).text
    # memanggil beautysoup
    soup = bs(request, "lxml")
    #menampilkan list berita
    daftar_berita = soup.find("div","list media_rows list-berita")
    # menampil isi artikel
    artikel = daftar_berita.find_all("article") 

    for tampil in artikel:
      #judul
      judul = tampil.find_all("h2")
      judul = [ele.text.strip() for ele in judul]
      # deskripsi
      isi  = tampil.find_all("p")
      isi  = [ele.text.strip() for ele in isi]
      data.append([judul[0], isi[0]])
  return data

# %%
berita=scrape_detik(50)
isi_berita = pd.DataFrame(berita)
isi_berita.columns=["Judul","Isi KOnten"]
isi_berita
# Out:
#                                                 Judul  \
# 0   RK Jadi Capres Alternatif Populer, Pengamat: S...
# 1   Duduk Perkara Dihancurkannya Rumah Singgah Bun...
# 2   Jabar Hari Ini: Hukuman Lebih Berat untuk Doni...
# 3   Indonesia Fashion Week 2023 Dimeriahkan 200 De...
# 4   Duet Anies-Sandi Mencuat di Survei Voxpol, PKS...
# ..                                                ...
# 84  Bautista Semprot Sampanye, Toprak Merasa Tak D...
# 85      Cerita Sandiaga Uno Setia dengan Mobil Kijang
# 86   Yang Baru di Sirkuit Mandalika Jelang Gelar WSBK
# 87  Jajal Motor Listrik Electrum, Sandiaga Uno: Pe...
# 88  Jokowi Perintahkan Sandiaga Uno: Lokasi Wisata...
#
#                                            Isi KOnten
# 0   Ridwan Kamil jadi capres alternatif berdasarka...
# 1   Rumah Singgah Bung Karno di Padang dihancurkan...
# 2   Ragam peristiwa terjadi di Jabar hari ini, Rab...
# 3   Indonesia Fashion Week 2023 digelar mulai dari...
# 4   Voxpol Center Research and Consulting melakuka...
# ..                                                ...
# 84  Toprak Razgatlioglu tidak suka disemprot sampa...
# 85  Menteri Pariwisata dan Ekonomi Kreatif (Menpar...
# 86  Menyambut World Superbike (SBK) bulan depan, S...
# 87  Ia pun mengapresiasi Electrum yang akan memper...
# 88  Pemerintah pusat dan daerah diminta beralih me...
#
# [89 rows x 2 columns]

# %%
isi_berita.to_csv("detik.csv")
